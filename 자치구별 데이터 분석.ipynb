# %%
import requests
import json
import pandas as pd
import numpy as np
import folium
print(folium.__version__)
# Out:
# 0.12.1.post1

# %%
data = './hangeul.csv'
df = pd.read_csv(data, encoding='CP949')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   자치구                     25 non-null     object
#  1   2015 total household    25 non-null     object
#  2   2015 1person household  25 non-null     object
#  3   2015 index              25 non-null     float64
#  4   2020 total household    25 non-null     object
#  5   2020 1person household  25 non-null     object
#  6   2020 index              25 non-null     float64
#  7   sale price              25 non-null     int64
#  8   rent price              25 non-null     int64
#  9   전체 비율                   25 non-null     int64
#  10  20대                     25 non-null     object
#  11  30대                     25 non-null     object
#  12  40대                     25 non-null     object
#  13  50대                     25 non-null     object
# ...

# %%
for i in df.columns[1:3]:
  df[i] = [int(j.replace(",","")) for j in df[i]]
for i in df.columns[4:6]:
  df[i] = [int(j.replace(",","")) for j in df[i]]
for i in df.columns[10:]:
  df[i] = [int(j.replace(",","")) for j in df[i]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   자치구                     25 non-null     object
#  1   2015 total household    25 non-null     int64
#  2   2015 1person household  25 non-null     int64
#  3   2015 index              25 non-null     float64
#  4   2020 total household    25 non-null     int64
#  5   2020 1person household  25 non-null     int64
#  6   2020 index              25 non-null     float64
#  7   sale price              25 non-null     int64
#  8   rent price              25 non-null     int64
#  9   전체 비율                   25 non-null     int64
#  10  20대                     25 non-null     int64
#  11  30대                     25 non-null     int64
#  12  40대                     25 non-null     int64
#  13  50대                     25 non-null     int64
# ...

# %%
df
# Out:
#      자치구  2015 total household  2015 1person household  2015 index  \
# 0    종로구                 61580                   22776   36.986034
# 1     중구                 51205                   19161   37.420174
# 2    용산구                 90313                   31025   34.352751
# 3    성동구                114719                   35259   30.735101
# 4    광진구                147718                   54210   36.698304
# 5   동대문구                146677                   52884   36.054733
# 6    중랑구                157537                   45138   28.652317
# 7    성북구                174257                   52005   29.843851
# 8    강북구                125666                   35787   28.477870
# 9    도봉구                124981                   27348   21.881726
# 10   노원구                204836                   46129   22.519967
# 11   은평구                179752                   43936   24.442565
# 12  서대문구                121034                   40160   33.180759
# ...

# %%
m2030 = folium.Map(
    location=[37.566345, 126.977893],
    tiles='cartodbpositron'
)

fmap = folium.Choropleth(
    geo_data = geo_json,
    name = 'choropleth', 
    data = df[['자치구', '2030']], 
    columns = ['자치구', '2030'],
    legend_name = '1인가구 수(20대, 30대)',
    key_on = 'feature.properties.name', # geo_data에서 지역의 이름이 저장되어 있는 곳
    fill_color = 'Purples',
    fill_opacity = 0.7, 
    line_opacity = 0.1, 
    highlight = True
).add_to(m2030)

fmap.geojson.zoom_on_click = False
fmap.geojson.add_child(
    folium.features.GeoJsonTooltip(['name'], labels=False)
)
m2030
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m4050 = folium.Map(
    location=[37.566345, 126.977893],
    tiles='cartodbpositron'
)

fmap = folium.Choropleth(
    geo_data = geo_json,
    name = 'choropleth', 
    data = df[['자치구', '4050']], 
    columns = ['자치구', '4050'],
    legend_name = '1인가구 수(40대, 50대)',
    key_on = 'feature.properties.name', # geo_data에서 지역의 이름이 저장되어 있는 곳
    fill_color = 'Purples',
    fill_opacity = 0.7, 
    line_opacity = 0.1, 
    highlight = True
).add_to(m4050)

fmap.geojson.zoom_on_click = False
fmap.geojson.add_child(
    folium.features.GeoJsonTooltip(['name'], labels=False)
)
m4050
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m6070 = folium.Map(
    location=[37.566345, 126.977893],
    tiles='cartodbpositron'
)

fmap = folium.Choropleth(
    geo_data = geo_json,
    name = 'choropleth', 
    data = df[['자치구', '60-']], 
    columns = ['자치구', '60-'],
    legend_name = '1인가구 수(60대 이상)',
    key_on = 'feature.properties.name', # geo_data에서 지역의 이름이 저장되어 있는 곳
    fill_color = 'Purples',
    fill_opacity = 0.7, 
    line_opacity = 0.1, 
    highlight = True
).add_to(m6070)

fmap.geojson.zoom_on_click = False
fmap.geojson.add_child(
    folium.features.GeoJsonTooltip(['name'], labels=False)
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
